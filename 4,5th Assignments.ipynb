# %% [markdown]
# # 4th Assignment

# %% [markdown]
# # Employee-Attrition Dataset

# %% [markdown]
# # The first step is to import the libraries that are essential to the assignment

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report

pd.set_option("display.max_columns", None)

# %%
# dataset import
df = pd.read_csv('Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# Shape of the dataset
df.shape
# Out:
# (1470, 35)

# %%
df.isnull().sum()
# No null values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# # To be able to determine the correlation between string type variables and other, we need to convert them to integer with the help of dummy variable approach

# %%
df = pd.concat([df, pd.get_dummies(df[['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus']])], axis=1)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# Shape after converting
df.shape
# Out:
# (1470, 63)

# %% [markdown]
# # Let's get rid of string type columns

# %%
df = df.drop(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus'], axis=1)

# %%
df.shape
# Out:
# (1470, 57)

# %% [markdown]
# # There is no need to clean the data cause it is already a clean one without any null values

# %%
df.corr()
# Out:
#                                         Age  DailyRate  DistanceFromHome  \
# Age                                1.000000   0.010661         -0.001686
# DailyRate                          0.010661   1.000000         -0.004985
# DistanceFromHome                  -0.001686  -0.004985          1.000000
# Education                          0.208034  -0.016806          0.021042
# EmployeeCount                           NaN        NaN               NaN
# EmployeeNumber                    -0.010145  -0.050990          0.032916
# EnvironmentSatisfaction            0.010146   0.018355         -0.016075
# HourlyRate                         0.024287   0.023381          0.031131
# JobInvolvement                     0.029820   0.046135          0.008783
# JobLevel                           0.509604   0.002966          0.005303
# JobSatisfaction                   -0.004892   0.030571         -0.003669
# MonthlyIncome                      0.497855   0.007707         -0.017014
# ...

# %% [markdown]
# # EDA

# %%
sns.lmplot(x='Attrition_Yes', y='YearsInCurrentRole', data=df)
plt.title('Attrition relation to ')
plt.show()

# %%
sns.lmplot(x='Attrition_Yes', y='Age', data=df)
plt.title('Attrition relation to ')
plt.show()

# %%
sns.lmplot(x='Attrition_Yes', y='JobLevel', data=df)
plt.title('Attrition relation to ')
plt.show()

# %%
sns.relplot(x='Attrition_Yes', y='StockOptionLevel', data=df)
plt.title('Attrition relation to ')
plt.show()

# %% [markdown]
# # Development and Evaluation of the Model

# %%
X = df.drop(['Attrition_Yes', 'Attrition_No', 'Attrition', 'OverTime', 'Over18'], axis=1)

y = df['Attrition_Yes']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train.shape
# Out:
# (1176, 52)

# %% [markdown]
# # Random Forest Model Development

# %%
rfc = RandomForestClassifier()
rfc = rfc.fit(X_train, y_train)

# %%
rfc.score(X_test, y_test) # calculate the score for the test set
# Out:
# 0.8197278911564626

# %% [markdown]
# # Accuracy = 82%

# %%
y_test_pred = rfc.predict(X_test) # predicted values
cm = confusion_matrix(y_test, y_test_pred) # confusion matrix to see the false/true negatives/positives
cm
# Out:
# array([[234,   2],
#        [ 51,   7]], dtype=int64)

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90       236
#            1       0.78      0.12      0.21        58
#
#     accuracy                           0.82       294
#    macro avg       0.80      0.56      0.55       294
# weighted avg       0.81      0.82      0.76       294
